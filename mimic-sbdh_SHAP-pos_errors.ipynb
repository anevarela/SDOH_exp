# %%
import json
import pandas as pd

with open ("json_file_from_SHAPexplainability", "r") as f:
    ex = json.load(f)

df = pd.read_csv("csv_file_with_MIMIC_data")

len(ex), len(df)
# Out:
# (1425, 1425)

# %%
from spacy.lang.es.stop_words import STOP_WORDS
# Out:
# /gaueko0/users/avarela/venv/lib/python3.9/site-packages/cupy/_environment.py:596: UserWarning:
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy, cupy-cuda12x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------
#
#   warnings.warn(f'''

# %%
rows = []
for filename, labels in ex.items():
    entry = {'file': filename}
    for label_name, values in labels.items():
        entry[f"{label_name}_pred"] = values.get('prediction')
        entry[f"{label_name}_conf"] = values.get('confidence')
        
        entry[f"{label_name}_thresholds"] = values.get('thresholds', {})
    rows.append(entry)

json_df = pd.DataFrame(rows)

# %%
df['file'] = df['file'].astype(str)
json_df['file'] = json_df['file'].astype(str)

final_df = pd.merge(df, json_df, how = "right", on = "file")

# %%
from sklearn.metrics import classification_report

categories = [
    "sdoh_community_present", "sdoh_community_absent", "sdoh_education", "sdoh_economics", 
    "sdoh_environment", "behavior_alcohol", "behavior_tobacco", "behavior_drug"
]

for cat in categories:

    print(f"Category {cat}")
    
    pred_col = f"{cat}_pred"

    report = classification_report(
        final_df[cat], 
        final_df[pred_col], 
        output_dict=True
    )
    print(pd.DataFrame(report))
    print("\n")
# Out:
# Category sdoh_community_present
#                   0.0         1.0  accuracy    macro avg  weighted avg
# precision    0.953757    0.985651  0.974035     0.969704      0.974281
# recall       0.974409    0.973828  0.974035     0.974119      0.974035
# f1-score     0.963973    0.979704  0.974035     0.971838      0.974096
# support    508.000000  917.000000  0.974035  1425.000000   1425.000000
#
#
# Category sdoh_community_absent
#                    0.0         1.0  accuracy    macro avg  weighted avg
# precision     0.991406    0.910345  0.983158     0.950876      0.983272
# recall        0.989860    0.923077  0.983158     0.956468      0.983158
# f1-score      0.990632    0.916667  0.983158     0.953649      0.983210
# support    1282.000000  143.000000  0.983158  1425.000000   1425.000000
#
#
# Category sdoh_education
#                    0.0        1.0  accuracy    macro avg  weighted avg
# precision     0.998555   0.780488  0.992281     0.889521      0.993352
# recall        0.993530   0.941176  0.992281     0.967353      0.992281
# f1-score      0.996036   0.853333  0.992281     0.924685      0.992631
# support    1391.000000  34.000000  0.992281  1425.000000   1425.000000
#
#
# Category sdoh_economics
#                   0.0         1.0         2.0  accuracy    macro avg  \
# precision    0.958716    0.832432    0.891304  0.924912     0.894151
# recall       0.946772    0.810526    0.931818  0.924912     0.896372
# f1-score     0.952707    0.821333    0.911111  0.924912     0.895050
# support    883.000000  190.000000  352.000000  0.924912  1425.000000
#
#            weighted avg
# precision      0.925226
# recall         0.924912
# f1-score       0.924915
# support     1425.000000
#
#
# Category sdoh_environment
#                   0.0         1.0        2.0  accuracy    macro avg  \
# precision    0.957774    0.965440   1.000000  0.962807     0.974405
# recall       0.948669    0.976325   0.583333  0.962807     0.836109
# f1-score     0.953200    0.970852   0.736842  0.962807     0.886965
# support    526.000000  887.000000  12.000000  0.962807  1425.000000
#
#            weighted avg
# precision      0.962901
# recall         0.962807
# f1-score       0.962366
# support     1425.000000
#
#
# Category behavior_alcohol
#                   0.0         1.0         2.0         3.0        4.0  \
# precision    0.925595    0.904988    0.790476    0.961382   0.746479
# recall       0.922849    0.915865    0.821782    0.940358   0.779412
# f1-score     0.924220    0.910394    0.805825    0.950754   0.762590
# support    337.000000  416.000000  101.000000  503.000000  68.000000
#
#            accuracy    macro avg  weighted avg
# precision  0.912982     0.865784      0.914087
# recall     0.912982     0.876053      0.912982
# f1-score   0.912982     0.870757      0.913445
# support    0.912982  1425.000000   1425.000000
#
#
# Category behavior_tobacco
#                   0.0         1.0         2.0         3.0        4.0  \
# precision    0.884892    0.921951    0.929907    0.966368   0.911765
# recall       0.935361    0.887324    0.949881    0.949339   0.815789
# f1-score     0.909427    0.904306    0.939787    0.957778   0.861111
# support    263.000000  213.000000  419.000000  454.000000  76.000000
#
#            accuracy    macro avg  weighted avg
# precision  0.930526     0.922976      0.931058
# recall     0.930526     0.907539      0.930526
# f1-score   0.930526     0.914482      0.930416
# support    0.930526  1425.000000   1425.000000
#
#
# Category behavior_drug
#                   0.0        1.0        2.0         3.0        4.0  accuracy  \
# precision    0.976948   0.692308   0.666667    0.917073   0.700000  0.938246
# recall       0.975877   0.400000   0.842105    0.944724   0.656250  0.938246
# f1-score     0.976413   0.507042   0.744186    0.930693   0.677419  0.938246
# support    912.000000  45.000000  38.000000  398.000000  32.000000  0.938246
#
#              macro avg  weighted avg
# precision     0.790599      0.936743
# recall        0.763791      0.938246
# f1-score      0.767151      0.935914
# support    1425.000000   1425.000000

# %%
import ast
from collections import defaultdict

def clean_ner(lista):
    hartu = defaultdict(list)

    lista = ast.literal_eval(lista)
    for instance in lista:
        if instance[1] != "O":
            hartu[instance[1][2:]].append(instance[0])

    return hartu

final_df["ner_kw"] = final_df["predicted_ner"].apply(clean_ner)

# %%
import string

translator = str.maketrans('', '', string.punctuation)

def clean_set(word_list):
    cleaned = set()
    for word in word_list:
        if not isinstance(word, str): continue
        c = word.strip().lower().translate(translator)
        c = ''.join([i for i in c if not i.isdigit()])
        if c and c not in STOP_WORDS:
            cleaned.add(c)
    return cleaned

# %%
for i in range(0,41):

    th = round(i*0.01, 2)
    evaluation_rows = []
    
    TARGET_THRESH = f"thresh_{th}" 

    print(f"-------------------------- TARGET THRESHOLD: {TARGET_THRESH} --------------------------")
    
    for ind, row in final_df.iterrows():
        ner_entities = row.get("ner_kw", {})
    
        for cat in categories:

            if "absent" in cat:
                continue
                
            pred_col = f"{cat}_pred"
            current_pred_class = row.get(pred_col)
            if "community" in cat:
                current_pred_class = 0
                if row.get(pred_col) == 1 and row.get("sdoh_community_absent_pred") == 0:
                    current_pred_class = "Present"
                elif row.get(pred_col) == 0 and row.get("sdoh_community_absent_pred") == 1:
                    current_pred_class = "Absent"
                elif row.get(pred_col) == 1 and row.get("sdoh_community_absent_pred") == 1:
                    current_pred_class = "Both"
                
            if current_pred_class in [0,4]:
                continue
    
            threshold_dict = row.get(f"{cat}_thresholds", {})
            lime_kws_raw = threshold_dict.get(TARGET_THRESH, [])
            
            if not isinstance(lime_kws_raw, list):
                lime_kws_raw = []
    
            ner_label = cat
            if "community" in ner_label: 
                ner_label = "sdoh_community"
                threshold_dict = row.get(f"sdoh_community_absent_thresholds", {})
                lime_kws_raw += threshold_dict.get(TARGET_THRESH, [])
                
            gt_raw = ner_entities.get(ner_label, [])
    
            lime_set = clean_set(lime_kws_raw)
            gt_set = clean_set(gt_raw)
    
            hits = 0
            for g_word in gt_set:
                if any(l_word == g_word for l_word in lime_set):
                    hits += 1
            
            precision = hits / len(lime_set) if len(lime_set) > 0 else 0
            recall = hits / len(gt_set) if len(gt_set) > 0 else 0
            f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
            evaluation_rows.append({
                "category": cat,
                "prediction_class": current_pred_class,
                "precision": precision,
                "recall": recall,
                "f1": f1,
                "lime_count": len(lime_set),
                "ner_count": len(gt_set)
            })
    
    results_df = pd.DataFrame(evaluation_rows)
    
    category_report = results_df.groupby(['category', 'prediction_class']).agg({
        'precision': 'mean',
        'recall': 'mean',
        'f1': 'mean',
        'category': 'count'
    }).rename(columns={'category': 'sample_count'}).reset_index()
    
    print(f"### Performance per category and label ###")
    print(category_report.to_string(index=False))
    print("\n")

    category_report = results_df.groupby(['category']).agg({
        'precision': 'mean',
        'recall': 'mean',
        'f1': 'mean',
        'category': 'count'
    }).rename(columns={'category': 'sample_count'}).reset_index()
    
    print(f"### Performance per category ###")
    print(category_report.to_string(index=False))
    print("\n")
    print("\n")
# Out:
# -------------------------- TARGET THRESHOLD: thresh_0.0 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.142533 0.899762 0.234763           421
#       behavior_alcohol                2   0.103225 0.910317 0.177139           105
#       behavior_alcohol                3   0.199272 0.922764 0.299180           492
#          behavior_drug                1   0.118710 0.910256 0.202673            26
#          behavior_drug                2   0.148750 0.864583 0.240633            48
#          behavior_drug                3   0.208118 0.928049 0.307147           410
#       behavior_tobacco                1   0.210416 0.917317 0.320228           205
#       behavior_tobacco                2   0.145760 0.843419 0.238222           428
#       behavior_tobacco                3   0.196551 0.926009 0.296587           446
# sdoh_community_present           Absent   0.071658 0.850575 0.129717            29
# sdoh_community_present             Both   0.163999 0.978879 0.269726           116
# sdoh_community_present          Present   0.145014 0.959072 0.238324           790
#         sdoh_economics                1   0.079968 0.851351 0.142546           185
#         sdoh_economics                2   0.109925 0.911051 0.189088           368
#         sdoh_education                1   0.108633 0.707317 0.181636            41
#       sdoh_environment                1   0.264294 0.924155 0.371367           897
#       sdoh_environment                2   0.079677 0.714286 0.137838             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.165901 0.911968 0.259953          1018
#          behavior_drug   0.197427 0.920799 0.294938           484
#       behavior_tobacco   0.179038 0.891597 0.277927          1079
# sdoh_community_present   0.145094 0.958164 0.238852           935
#         sdoh_economics   0.099903 0.891079 0.173518           553
#         sdoh_education   0.108633 0.707317 0.181636            41
#       sdoh_environment   0.262865 0.922529 0.369559           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.01 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.264588 0.894141 0.389965           421
#       behavior_alcohol                2   0.240704 0.884921 0.355580           105
#       behavior_alcohol                3   0.358702 0.920732 0.476742           492
#          behavior_drug                1   0.345147 0.858974 0.463645            26
#          behavior_drug                2   0.324111 0.839583 0.446879            48
#          behavior_drug                3   0.408822 0.918699 0.522246           410
#       behavior_tobacco                1   0.427313 0.896992 0.541404           205
#       behavior_tobacco                2   0.236034 0.798832 0.344779           428
#       behavior_tobacco                3   0.342995 0.923019 0.461775           446
# sdoh_community_present           Absent   0.139496 0.850575 0.233900            29
# sdoh_community_present             Both   0.390178 0.966195 0.530920           116
# sdoh_community_present          Present   0.433396 0.951814 0.549601           790
#         sdoh_economics                1   0.314348 0.844595 0.424210           185
#         sdoh_economics                2   0.396450 0.895652 0.512304           368
#         sdoh_education                1   0.326423 0.682927 0.412667            41
#       sdoh_environment                1   0.466844 0.919658 0.572204           897
#       sdoh_environment                2   0.332143 0.714286 0.412698             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.307610 0.906041 0.428358          1018
#          behavior_drug   0.397001 0.907645 0.511624           484
#       behavior_tobacco   0.316587 0.868814 0.430496          1079
# sdoh_community_present   0.418919 0.950458 0.537492           935
#         sdoh_economics   0.368984 0.878571 0.482833           553
#         sdoh_education   0.326423 0.682927 0.412667            41
#       sdoh_environment   0.465801 0.918068 0.570969           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.02 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.341364 0.881869 0.472324           421
#       behavior_alcohol                2   0.296886 0.857143 0.416562           105
#       behavior_alcohol                3   0.437123 0.918699 0.556380           492
#          behavior_drug                1   0.437821 0.846154 0.553022            26
#          behavior_drug                2   0.457093 0.768056 0.539094            48
#          behavior_drug                3   0.487108 0.917480 0.594932           410
#       behavior_tobacco                1   0.519286 0.879756 0.615835           205
#       behavior_tobacco                2   0.295884 0.765771 0.399061           428
#       behavior_tobacco                3   0.416072 0.920030 0.536092           446
# sdoh_community_present           Absent   0.271987 0.850575 0.371817            29
# sdoh_community_present             Both   0.474557 0.956055 0.607880           116
# sdoh_community_present          Present   0.524017 0.945105 0.630726           790
#         sdoh_economics                1   0.379721 0.844595 0.491953           185
#         sdoh_economics                2   0.487574 0.895652 0.594803           368
#         sdoh_education                1   0.383856 0.682927 0.465822            41
#       sdoh_environment                1   0.564464 0.912783 0.655421           897
#       sdoh_environment                2   0.464286 0.714286 0.533333             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.383057 0.897119 0.507197          1018
#          behavior_drug   0.481484 0.898829 0.587143           484
#       behavior_tobacco   0.388008 0.851189 0.496887          1079
# sdoh_community_present   0.510064 0.943532 0.619861           935
#         sdoh_economics   0.451493 0.878571 0.560395           553
#         sdoh_education   0.383856 0.682927 0.465822            41
#       sdoh_environment   0.563688 0.911246 0.654475           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.03 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.393076 0.877039 0.519125           421
#       behavior_alcohol                2   0.350068 0.792063 0.444431           105
#       behavior_alcohol                3   0.489320 0.914634 0.602221           492
#          behavior_drug                1   0.574359 0.717949 0.592582            26
#          behavior_drug                2   0.559127 0.740278 0.603694            48
#          behavior_drug                3   0.534233 0.915041 0.637000           410
#       behavior_tobacco                1   0.576423 0.850894 0.647158           205
#       behavior_tobacco                2   0.327584 0.713902 0.419076           428
#       behavior_tobacco                3   0.467494 0.916667 0.581620           446
# sdoh_community_present           Absent   0.407266 0.850575 0.509797            29
# sdoh_community_present             Both   0.512970 0.942816 0.640169           116
# sdoh_community_present          Present   0.593251 0.934262 0.683667           790
#         sdoh_economics                1   0.432014 0.836486 0.537169           185
#         sdoh_economics                2   0.516276 0.892255 0.619244           368
#         sdoh_education                1   0.452439 0.664634 0.515099            41
#       sdoh_environment                1   0.620799 0.904422 0.697152           897
#       sdoh_environment                2   0.500000 0.714286 0.571429             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.435155 0.886444 0.551581          1018
#          behavior_drug   0.538858 0.887121 0.631311           484
#       behavior_tobacco   0.432692 0.823741 0.529596          1079
# sdoh_community_present   0.577523 0.932727 0.672878           935
#         sdoh_economics   0.488087 0.873599 0.591787           553
#         sdoh_education   0.452439 0.664634 0.515099            41
#       sdoh_environment   0.619864 0.902950 0.696178           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.04 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.431846 0.868963 0.551454           421
#       behavior_alcohol                2   0.384558 0.774603 0.479448           105
#       behavior_alcohol                3   0.517397 0.906504 0.625692           492
#          behavior_drug                1   0.616026 0.717949 0.615659            26
#          behavior_drug                2   0.613194 0.722917 0.618700            48
#          behavior_drug                3   0.562276 0.908943 0.658647           410
#       behavior_tobacco                1   0.610418 0.820407 0.654553           205
#       behavior_tobacco                2   0.346217 0.680257 0.429263           428
#       behavior_tobacco                3   0.507591 0.916667 0.614277           446
# sdoh_community_present           Absent   0.454598 0.850575 0.561905            29
# sdoh_community_present             Both   0.552675 0.910489 0.662117           116
# sdoh_community_present          Present   0.639039 0.924135 0.713973           790
#         sdoh_economics                1   0.460766 0.831081 0.560635           185
#         sdoh_economics                2   0.544339 0.885462 0.640114           368
#         sdoh_education                1   0.504472 0.664634 0.548432            41
#       sdoh_environment                1   0.651534 0.899220 0.718231           897
#       sdoh_environment                2   0.642857 0.714286 0.666667             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.468316 0.877374 0.579906          1018
#          behavior_drug   0.570213 0.880234 0.652376           484
#       behavior_tobacco   0.463116 0.804603 0.548541          1079
# sdoh_community_present   0.622603 0.920160 0.702823           935
#         sdoh_economics   0.516380 0.867269 0.613525           553
#         sdoh_education   0.504472 0.664634 0.548432            41
#       sdoh_environment   0.651467 0.897788 0.717832           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.05 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.454394 0.845606 0.564743           421
#       behavior_alcohol                2   0.398413 0.746032 0.486304           105
#       behavior_alcohol                3   0.537940 0.888211 0.637747           492
#          behavior_drug                1   0.583974 0.685897 0.593864            26
#          behavior_drug                2   0.663542 0.699653 0.622272            48
#          behavior_drug                3   0.590163 0.904065 0.679617           410
#       behavior_tobacco                1   0.648873 0.793984 0.664843           205
#       behavior_tobacco                2   0.357605 0.645132 0.428234           428
#       behavior_tobacco                3   0.532495 0.911435 0.634451           446
# sdoh_community_present           Absent   0.532759 0.833333 0.614614            29
# sdoh_community_present             Both   0.577730 0.869971 0.664972           116
# sdoh_community_present          Present   0.675499 0.911941 0.735964           790
#         sdoh_economics                1   0.488520 0.825676 0.581840           185
#         sdoh_economics                2   0.564266 0.880480 0.652290           368
#         sdoh_education                1   0.502439 0.656504 0.543786            41
#       sdoh_environment                1   0.669520 0.894203 0.730793           897
#       sdoh_environment                2   0.642857 0.714286 0.666667             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.488998 0.855927 0.591935          1018
#          behavior_drug   0.597107 0.872073 0.669323           484
#       behavior_tobacco   0.485233 0.783488 0.558426          1079
# sdoh_community_present   0.658942 0.904296 0.723393           935
#         sdoh_economics   0.538926 0.862146 0.628722           553
#         sdoh_education   0.502439 0.656504 0.543786            41
#       sdoh_environment   0.669314 0.892810 0.730297           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.06 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.473170 0.827989 0.575543           421
#       behavior_alcohol                2   0.400000 0.700000 0.477415           105
#       behavior_alcohol                3   0.540955 0.869919 0.636760           492
#          behavior_drug                1   0.609615 0.685897 0.613095            26
#          behavior_drug                2   0.632292 0.668403 0.591022            48
#          behavior_drug                3   0.615894 0.902439 0.697851           410
#       behavior_tobacco                1   0.660325 0.772927 0.663171           205
#       behavior_tobacco                2   0.363051 0.608139 0.420872           428
#       behavior_tobacco                3   0.561606 0.904709 0.655442           446
# sdoh_community_present           Absent   0.565517 0.833333 0.639080            29
# sdoh_community_present             Both   0.582995 0.846408 0.659970           116
# sdoh_community_present          Present   0.707958 0.888945 0.748422           790
#         sdoh_economics                1   0.507297 0.825676 0.592098           185
#         sdoh_economics                2   0.575136 0.871875 0.656768           368
#         sdoh_education                1   0.517073 0.648374 0.552613            41
#       sdoh_environment                1   0.682879 0.881847 0.736787           897
#       sdoh_environment                2   0.642857 0.714286 0.666667             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.498384 0.835052 0.595008          1018
#          behavior_drug   0.617183 0.867596 0.682704           484
#       behavior_tobacco   0.501602 0.762033 0.563865          1079
# sdoh_community_present   0.688037 0.881943 0.734057           935
#         sdoh_economics   0.552441 0.856420 0.635133           553
#         sdoh_education   0.517073 0.648374 0.552613            41
#       sdoh_environment   0.682570 0.880549 0.736244           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.07 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.481987 0.814727 0.578924           421
#       behavior_alcohol                2   0.396032 0.661111 0.464286           105
#       behavior_alcohol                3   0.547730 0.861789 0.640718           492
#          behavior_drug                1   0.583333 0.634615 0.576923            26
#          behavior_drug                2   0.597569 0.609375 0.553522            48
#          behavior_drug                3   0.627114 0.881707 0.701452           410
#       behavior_tobacco                1   0.673902 0.748943 0.657096           205
#       behavior_tobacco                2   0.355179 0.543886 0.397942           428
#       behavior_tobacco                3   0.575246 0.884529 0.660930           446
# sdoh_community_present           Absent   0.585632 0.833333 0.654023            29
# sdoh_community_present             Both   0.605101 0.805460 0.659101           116
# sdoh_community_present          Present   0.727357 0.872869 0.754321           790
#         sdoh_economics                1   0.509099 0.804054 0.588108           185
#         sdoh_economics                2   0.581748 0.862274 0.658010           368
#         sdoh_education                1   0.525203 0.636179 0.546341            41
#       sdoh_environment                1   0.695559 0.879989 0.745867           897
#       sdoh_environment                2   0.642857 0.714286 0.666667             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.504895 0.821627 0.596965          1018
#          behavior_drug   0.621832 0.841426 0.680091           484
#       behavior_tobacco   0.506697 0.723648 0.555884          1079
# sdoh_community_present   0.707793 0.863280 0.739397           935
#         sdoh_economics   0.557444 0.842797 0.634625           553
#         sdoh_education   0.525203 0.636179 0.546341            41
#       sdoh_environment   0.695151 0.878706 0.745254           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.08 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.490063 0.802059 0.580981           421
#       behavior_alcohol                2   0.389683 0.632540 0.449683           105
#       behavior_alcohol                3   0.544783 0.838415 0.632859           492
#          behavior_drug                1   0.602564 0.596154 0.566667            26
#          behavior_drug                2   0.503472 0.537500 0.489087            48
#          behavior_drug                3   0.635976 0.874390 0.706167           410
#       behavior_tobacco                1   0.660244 0.728618 0.643786           205
#       behavior_tobacco                2   0.353076 0.502804 0.383100           428
#       behavior_tobacco                3   0.585052 0.865097 0.662494           446
# sdoh_community_present           Absent   0.579885 0.821839 0.644828            29
# sdoh_community_present             Both   0.608261 0.760920 0.645459           116
# sdoh_community_present          Present   0.734476 0.856097 0.752467           790
#         sdoh_economics                1   0.521532 0.790541 0.594775           185
#         sdoh_economics                2   0.592482 0.860915 0.664933           368
#         sdoh_education                1   0.529268 0.599593 0.530081            41
#       sdoh_environment                1   0.703010 0.871999 0.747523           897
#       sdoh_environment                2   0.642857 0.714286 0.666667             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.506156 0.802145 0.592511          1018
#          behavior_drug   0.621040 0.826033 0.677145           484
#       behavior_tobacco   0.507322 0.695459 0.548114          1079
# sdoh_community_present   0.714022 0.843226 0.735853           935
#         sdoh_economics   0.568746 0.837372 0.641462           553
#         sdoh_education   0.529268 0.599593 0.530081            41
#       sdoh_environment   0.702544 0.870778 0.746897           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.09 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.494220 0.781671 0.577949           421
#       behavior_alcohol                2   0.386508 0.599206 0.438254           105
#       behavior_alcohol                3   0.545630 0.811992 0.626897           492
#          behavior_drug                1   0.564103 0.583333 0.547436            26
#          behavior_drug                2   0.461806 0.488889 0.444643            48
#          behavior_drug                3   0.643333 0.857724 0.705273           410
#       behavior_tobacco                1   0.660650 0.716016 0.642009           205
#       behavior_tobacco                2   0.348248 0.474766 0.370316           428
#       behavior_tobacco                3   0.592900 0.847160 0.664138           446
# sdoh_community_present           Absent   0.585632 0.821839 0.648276            29
# sdoh_community_present             Both   0.594325 0.719971 0.622409           116
# sdoh_community_present          Present   0.747553 0.833629 0.753327           790
#         sdoh_economics                1   0.533514 0.787838 0.603243           185
#         sdoh_economics                2   0.603714 0.848687 0.668375           368
#         sdoh_education                1   0.512195 0.593496 0.528455            41
#       sdoh_environment                1   0.708510 0.864567 0.749143           897
#       sdoh_environment                2   0.642857 0.714286 0.666667             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.507957 0.777505 0.587197          1018
#          behavior_drug   0.621074 0.806405 0.670946           484
#       behavior_tobacco   0.508727 0.674529 0.543385          1079
# sdoh_community_present   0.723520 0.819162 0.733827           935
#         sdoh_economics   0.580229 0.828330 0.646586           553
#         sdoh_education   0.512195 0.593496 0.528455            41
#       sdoh_environment   0.708001 0.863403 0.748504           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.1 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.503761 0.764450 0.577152           421
#       behavior_alcohol                2   0.369048 0.555556 0.413016           105
#       behavior_alcohol                3   0.528015 0.771341 0.602575           492
#          behavior_drug                1   0.602564 0.583333 0.564103            26
#          behavior_drug                2   0.440972 0.450694 0.413393            48
#          behavior_drug                3   0.636545 0.825203 0.691231           410
#       behavior_tobacco                1   0.644634 0.680650 0.620012           205
#       behavior_tobacco                2   0.332555 0.436799 0.348887           428
#       behavior_tobacco                3   0.601532 0.826981 0.664051           446
# sdoh_community_present           Absent   0.611494 0.821839 0.668966            29
# sdoh_community_present             Both   0.595710 0.704885 0.617994           116
# sdoh_community_present          Present   0.758523 0.815190 0.753168           790
#         sdoh_economics                1   0.536937 0.779730 0.605225           185
#         sdoh_economics                2   0.605888 0.831929 0.665386           368
#         sdoh_education                1   0.487805 0.577236 0.508943            41
#       sdoh_environment                1   0.712542 0.853047 0.747303           897
#       sdoh_environment                2   0.714286 0.714286 0.714286             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.501588 0.746234 0.572509          1018
#          behavior_drug   0.615324 0.775069 0.656848           484
#       behavior_tobacco   0.503027 0.644408 0.530670          1079
# sdoh_community_present   0.733764 0.801711 0.733786           935
#         sdoh_economics   0.582821 0.814467 0.645260           553
#         sdoh_education   0.487805 0.577236 0.508943            41
#       sdoh_environment   0.712555 0.851973 0.747048           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.11 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.499010 0.732383 0.563522           421
#       behavior_alcohol                2   0.343651 0.522222 0.384762           105
#       behavior_alcohol                3   0.523205 0.744919 0.592141           492
#          behavior_drug                1   0.615385 0.583333 0.576923            26
#          behavior_drug                2   0.447917 0.429861 0.413393            48
#          behavior_drug                3   0.639634 0.810569 0.690244           410
#       behavior_tobacco                1   0.618699 0.639837 0.591208           205
#       behavior_tobacco                2   0.325935 0.412266 0.337817           428
#       behavior_tobacco                3   0.599776 0.801570 0.657997           446
# sdoh_community_present           Absent   0.656322 0.787356 0.686207            29
# sdoh_community_present             Both   0.597434 0.685489 0.611501           116
# sdoh_community_present          Present   0.760675 0.796392 0.745256           790
#         sdoh_economics                1   0.538739 0.768919 0.603243           185
#         sdoh_economics                2   0.601812 0.802310 0.653727           368
#         sdoh_education                1   0.463415 0.528455 0.476423            41
#       sdoh_environment                1   0.711706 0.830676 0.739117           897
#       sdoh_environment                2   0.714286 0.714286 0.714286             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.494679 0.716765 0.558916          1018
#          behavior_drug   0.619318 0.760606 0.656700           484
#       behavior_tobacco   0.494748 0.616420 0.518304          1079
# sdoh_community_present   0.737186 0.782353 0.726830           935
#         sdoh_economics   0.580711 0.791139 0.636838           553
#         sdoh_education   0.463415 0.528455 0.476423            41
#       sdoh_environment   0.711726 0.829775 0.738925           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.12 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.498219 0.714766 0.555525           421
#       behavior_alcohol                2   0.340476 0.503175 0.377143           105
#       behavior_alcohol                3   0.524560 0.722561 0.586382           492
#          behavior_drug                1   0.615385 0.583333 0.576923            26
#          behavior_drug                2   0.406250 0.413194 0.389583            48
#          behavior_drug                3   0.640041 0.797154 0.686504           410
#       behavior_tobacco                1   0.605691 0.597154 0.562462           205
#       behavior_tobacco                2   0.307438 0.368263 0.309935           428
#       behavior_tobacco                3   0.591181 0.778027 0.644918           446
# sdoh_community_present           Absent   0.652299 0.752874 0.667816            29
# sdoh_community_present             Both   0.603181 0.645690 0.597031           116
# sdoh_community_present          Present   0.738460 0.759958 0.718794           790
#         sdoh_economics                1   0.541892 0.741892 0.599459           185
#         sdoh_economics                2   0.594158 0.766984 0.639312           368
#         sdoh_education                1   0.475610 0.516260 0.476423            41
#       sdoh_environment                1   0.706522 0.813211 0.729652           897
#       sdoh_environment                2   0.714286 0.714286 0.714286             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.494679 0.696709 0.552039          1018
#          behavior_drug   0.615530 0.747590 0.651171           484
#       behavior_tobacco   0.481387 0.581124 0.496377          1079
# sdoh_community_present   0.719004 0.745561 0.702107           935
#         sdoh_economics   0.576673 0.758590 0.625980           553
#         sdoh_education   0.475610 0.516260 0.476423            41
#       sdoh_environment   0.706582 0.812445 0.729533           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.13 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.491884 0.688638 0.541409           421
#       behavior_alcohol                2   0.334921 0.488889 0.369524           105
#       behavior_alcohol                3   0.514397 0.702236 0.573171           492
#          behavior_drug                1   0.576923 0.570513 0.557692            26
#          behavior_drug                2   0.385417 0.402778 0.375694            48
#          behavior_drug                3   0.636382 0.772764 0.677317           410
#       behavior_tobacco                1   0.604878 0.579675 0.554634           205
#       behavior_tobacco                2   0.283294 0.335164 0.285325           428
#       behavior_tobacco                3   0.582773 0.755605 0.633184           446
# sdoh_community_present           Absent   0.678161 0.752874 0.680460            29
# sdoh_community_present             Both   0.585920 0.614799 0.572906           116
# sdoh_community_present          Present   0.735738 0.740127 0.708794           790
#         sdoh_economics                1   0.539189 0.720270 0.591532           185
#         sdoh_economics                2   0.587274 0.746603 0.628714           368
#         sdoh_education                1   0.475610 0.504065 0.468293            41
#       sdoh_environment                1   0.698253 0.797696 0.718726           897
#       sdoh_environment                2   0.571429 0.571429 0.571429             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.486575 0.674607 0.539031          1018
#          behavior_drug   0.608299 0.725207 0.640978           484
#       behavior_tobacco   0.468180 0.555406 0.480277          1079
# sdoh_community_present   0.715365 0.724973 0.691057           935
#         sdoh_economics   0.571187 0.737794 0.616275           553
#         sdoh_education   0.475610 0.504065 0.468293            41
#       sdoh_environment   0.697271 0.795944 0.717586           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.14 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.495447 0.674782 0.538084           421
#       behavior_alcohol                2   0.314286 0.441270 0.340952           105
#       behavior_alcohol                3   0.490684 0.667683 0.546070           492
#          behavior_drug                1   0.538462 0.506410 0.500000            26
#          behavior_drug                2   0.375000 0.340278 0.345139            48
#          behavior_drug                3   0.625407 0.744715 0.660407           410
#       behavior_tobacco                1   0.602439 0.562602 0.546179           205
#       behavior_tobacco                2   0.247079 0.290693 0.248053           428
#       behavior_tobacco                3   0.571562 0.728700 0.616966           446
# sdoh_community_present           Absent   0.563218 0.655172 0.579310            29
# sdoh_community_present             Both   0.594540 0.610201 0.573502           116
# sdoh_community_present          Present   0.727405 0.726730 0.699397           790
#         sdoh_economics                1   0.550450 0.714865 0.597477           185
#         sdoh_economics                2   0.581295 0.731658 0.619384           368
#         sdoh_education                1   0.475610 0.504065 0.468293            41
#       sdoh_environment                1   0.693051 0.783017 0.709659           897
#       sdoh_environment                2   0.571429 0.571429 0.571429             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.474460 0.647266 0.521611          1018
#          behavior_drug   0.595902 0.691804 0.620523           484
#       behavior_tobacco   0.448718 0.523401 0.457183          1079
# sdoh_community_present   0.705829 0.710053 0.680053           935
#         sdoh_economics   0.570976 0.726040 0.612055           553
#         sdoh_education   0.475610 0.504065 0.468293            41
#       sdoh_environment   0.692109 0.781379 0.708589           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.15 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.494854 0.664093 0.533967           421
#       behavior_alcohol                2   0.280952 0.398413 0.304444           105
#       behavior_alcohol                3   0.476118 0.642276 0.528117           492
#          behavior_drug                1   0.538462 0.506410 0.500000            26
#          behavior_drug                2   0.385417 0.329861 0.341667            48
#          behavior_drug                3   0.613211 0.715447 0.642683           410
#       behavior_tobacco                1   0.580488 0.534146 0.521789           205
#       behavior_tobacco                2   0.219626 0.250584 0.218614           428
#       behavior_tobacco                3   0.563714 0.709641 0.606129           446
# sdoh_community_present           Absent   0.580460 0.655172 0.590805            29
# sdoh_community_present             Both   0.597414 0.589799 0.562651           116
# sdoh_community_present          Present   0.718333 0.714241 0.690579           790
#         sdoh_economics                1   0.557658 0.714865 0.602883           185
#         sdoh_economics                2   0.572237 0.709918 0.605525           368
#         sdoh_education                1   0.475610 0.504065 0.468293            41
#       sdoh_environment                1   0.686734 0.775139 0.703175           897
#       sdoh_environment                2   0.571429 0.571429 0.571429             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.463736 0.626146 0.507466          1018
#          behavior_drug   0.586605 0.665978 0.605165           484
#       behavior_tobacco   0.430414 0.494208 0.436392          1079
# sdoh_community_present   0.699055 0.696970 0.671613           935
#         sdoh_economics   0.567360 0.711573 0.604641           553
#         sdoh_education   0.475610 0.504065 0.468293            41
#       sdoh_environment   0.685841 0.773562 0.702154           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.16 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.500594 0.649248 0.531196           421
#       behavior_alcohol                2   0.276190 0.385714 0.299683           105
#       behavior_alcohol                3   0.465955 0.623984 0.515650           492
#          behavior_drug                1   0.538462 0.506410 0.500000            26
#          behavior_drug                2   0.364583 0.309028 0.324306            48
#          behavior_drug                3   0.599390 0.693496 0.626504           410
#       behavior_tobacco                1   0.565854 0.516260 0.506667           205
#       behavior_tobacco                2   0.202103 0.230140 0.201402           428
#       behavior_tobacco                3   0.558857 0.693199 0.598281           446
# sdoh_community_present           Absent   0.586207 0.655172 0.596552            29
# sdoh_community_present             Both   0.584195 0.568966 0.547092           116
# sdoh_community_present          Present   0.705169 0.693249 0.675889           790
#         sdoh_economics                1   0.570270 0.712162 0.609369           185
#         sdoh_economics                2   0.559103 0.697011 0.594022           368
#         sdoh_education                1   0.495935 0.491870 0.473171            41
#       sdoh_environment                1   0.681159 0.764363 0.695854           897
#       sdoh_environment                2   0.571429 0.571429 0.571429             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.460707 0.609856 0.499804          1018
#          behavior_drug   0.572831 0.645317 0.589738           484
#       behavior_tobacco   0.418675 0.475904 0.423448          1079
# sdoh_community_present   0.686471 0.676649 0.657449           935
#         sdoh_economics   0.562839 0.702080 0.599156           553
#         sdoh_education   0.495935 0.491870 0.473171            41
#       sdoh_environment   0.680310 0.762869 0.694890           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.17 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.497823 0.632621 0.523436           421
#       behavior_alcohol                2   0.258730 0.366667 0.282222           105
#       behavior_alcohol                3   0.446985 0.585366 0.490650           492
#          behavior_drug                1   0.538462 0.506410 0.500000            26
#          behavior_drug                2   0.354167 0.298611 0.317361            48
#          behavior_drug                3   0.582317 0.665854 0.604878           410
#       behavior_tobacco                1   0.560976 0.502033 0.497236           205
#       behavior_tobacco                2   0.192757 0.217679 0.191667           428
#       behavior_tobacco                3   0.541667 0.662930 0.577728           446
# sdoh_community_present           Absent   0.568966 0.620690 0.573563            29
# sdoh_community_present             Both   0.579167 0.563218 0.543480           116
# sdoh_community_present          Present   0.699156 0.678270 0.666733           790
#         sdoh_economics                1   0.569369 0.695946 0.603964           185
#         sdoh_economics                2   0.551630 0.684783 0.586232           368
#         sdoh_education                1   0.467480 0.455285 0.445528            41
#       sdoh_environment                1   0.674842 0.752657 0.688608           897
#       sdoh_environment                2   0.571429 0.571429 0.571429             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.448592 0.582351 0.482711          1018
#          behavior_drug   0.557335 0.620868 0.570730           484
#       behavior_tobacco   0.406935 0.455746 0.409299          1079
# sdoh_community_present   0.680232 0.662210 0.648552           935
#         sdoh_economics   0.557565 0.688517 0.592164           553
#         sdoh_education   0.467480 0.455285 0.445528            41
#       sdoh_environment   0.674041 0.751254 0.687700           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.18 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.489311 0.611243 0.512589           421
#       behavior_alcohol                2   0.220635 0.304762 0.237778           105
#       behavior_alcohol                3   0.428354 0.554878 0.468293           492
#          behavior_drug                1   0.480769 0.474359 0.461538            26
#          behavior_drug                2   0.333333 0.288194 0.303472            48
#          behavior_drug                3   0.570732 0.645935 0.590813           410
#       behavior_tobacco                1   0.534959 0.480081 0.476911           205
#       behavior_tobacco                2   0.193146 0.213396 0.190343           428
#       behavior_tobacco                3   0.538303 0.651719 0.572123           446
# sdoh_community_present           Absent   0.517241 0.568966 0.527586            29
# sdoh_community_present             Both   0.575575 0.550718 0.534038           116
# sdoh_community_present          Present   0.683755 0.656962 0.649391           790
#         sdoh_economics                1   0.562162 0.663514 0.589550           185
#         sdoh_economics                2   0.548460 0.671196 0.579438           368
#         sdoh_education                1   0.418699 0.406504 0.396748            41
#       sdoh_environment                1   0.670011 0.743553 0.682513           897
#       sdoh_environment                2   0.428571 0.428571 0.428571             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.432138 0.552390 0.462836          1018
#          behavior_drug   0.542355 0.601240 0.555372           484
#       behavior_tobacco   0.400757 0.445243 0.402595          1079
# sdoh_community_present   0.665169 0.641052 0.631302           935
#         sdoh_economics   0.553044 0.668626 0.582821           553
#         sdoh_education   0.418699 0.406504 0.396748            41
#       sdoh_environment   0.668142 0.741114 0.680547           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.19 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.486936 0.593428 0.504751           421
#       behavior_alcohol                2   0.220635 0.304762 0.237778           105
#       behavior_alcohol                3   0.422764 0.542683 0.460705           492
#          behavior_drug                1   0.480769 0.474359 0.461538            26
#          behavior_drug                2   0.302083 0.256944 0.272222            48
#          behavior_drug                3   0.553252 0.617073 0.569268           410
#       behavior_tobacco                1   0.521951 0.450000 0.455935           205
#       behavior_tobacco                2   0.172118 0.191199 0.170717           428
#       behavior_tobacco                3   0.530456 0.633782 0.560912           446
# sdoh_community_present           Absent   0.517241 0.568966 0.527586            29
# sdoh_community_present             Both   0.578448 0.539224 0.528866           116
# sdoh_community_present          Present   0.677426 0.643671 0.640235           790
#         sdoh_economics                1   0.570270 0.658108 0.593153           185
#         sdoh_economics                2   0.537138 0.655344 0.567029           368
#         sdoh_education                1   0.394309 0.394309 0.380488            41
#       sdoh_environment                1   0.665366 0.731680 0.675591           897
#       sdoh_environment                2   0.428571 0.428571 0.428571             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.428454 0.539129 0.455927          1018
#          behavior_drug   0.524449 0.573691 0.534022           484
#       behavior_tobacco   0.386701 0.423309 0.386191          1079
# sdoh_community_present   0.660178 0.628396 0.622924           935
#         sdoh_economics   0.548222 0.656269 0.575769           553
#         sdoh_education   0.394309 0.394309 0.380488            41
#       sdoh_environment   0.663532 0.729333 0.673678           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.2 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.480008 0.570863 0.492953           421
#       behavior_alcohol                2   0.225397 0.304762 0.240952           105
#       behavior_alcohol                3   0.404472 0.516260 0.439702           492
#          behavior_drug                1   0.442308 0.435897 0.423077            26
#          behavior_drug                2   0.302083 0.256944 0.272222            48
#          behavior_drug                3   0.536179 0.588211 0.547886           410
#       behavior_tobacco                1   0.507317 0.437805 0.442927           205
#       behavior_tobacco                2   0.152259 0.172508 0.153972           428
#       behavior_tobacco                3   0.511958 0.600523 0.537519           446
# sdoh_community_present           Absent   0.517241 0.568966 0.527586            29
# sdoh_community_present             Both   0.559770 0.491092 0.490647           116
# sdoh_community_present          Present   0.660970 0.623734 0.623948           790
#         sdoh_economics                1   0.571171 0.652703 0.592252           185
#         sdoh_economics                2   0.526721 0.631341 0.551178           368
#         sdoh_education                1   0.394309 0.386179 0.375610            41
#       sdoh_environment                1   0.658120 0.713564 0.664591           897
#       sdoh_environment                2   0.428571 0.428571 0.428571             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.417240 0.517027 0.441225          1018
#          behavior_drug   0.507920 0.547176 0.513843           484
#       behavior_tobacco   0.368397 0.399830 0.367408          1079
# sdoh_community_present   0.643957 0.605579 0.604422           935
#         sdoh_economics   0.541591 0.638487 0.564919           553
#         sdoh_education   0.394309 0.386179 0.375610            41
#       sdoh_environment   0.656342 0.711357 0.662763           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.21 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.455067 0.537807 0.466192           421
#       behavior_alcohol                2   0.169841 0.252381 0.193651           105
#       behavior_alcohol                3   0.395664 0.495935 0.427168           492
#          behavior_drug                1   0.442308 0.435897 0.423077            26
#          behavior_drug                2   0.218750 0.173611 0.188889            48
#          behavior_drug                3   0.523984 0.567480 0.532520           410
#       behavior_tobacco                1   0.499187 0.421951 0.431220           205
#       behavior_tobacco                2   0.138629 0.154984 0.139174           428
#       behavior_tobacco                3   0.497384 0.578102 0.520703           446
# sdoh_community_present           Absent   0.517241 0.568966 0.527586            29
# sdoh_community_present             Both   0.572701 0.491092 0.492679           116
# sdoh_community_present          Present   0.639030 0.605380 0.605594           790
#         sdoh_economics                1   0.557658 0.636486 0.577838           185
#         sdoh_economics                2   0.530344 0.620471 0.549457           368
#         sdoh_education                1   0.394309 0.386179 0.375610            41
#       sdoh_environment                1   0.645671 0.693125 0.650098           897
#       sdoh_environment                2   0.428571 0.428571 0.428571             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.396938 0.488130 0.419221          1018
#          behavior_drug   0.489325 0.521350 0.492562           484
#       behavior_tobacco   0.355422 0.380599 0.352363          1079
# sdoh_community_present   0.627023 0.590071 0.589166           935
#         sdoh_economics   0.539482 0.625829 0.558951           553
# ...
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.254912 0.278815 0.258481          1018
#          behavior_drug   0.324380 0.303375 0.308540           484
#       behavior_tobacco   0.234013 0.235867 0.227618          1079
# sdoh_community_present   0.454189 0.397754 0.412376           935
#         sdoh_economics   0.399638 0.403707 0.395841           553
#         sdoh_education   0.231707 0.203252 0.207317            41
#       sdoh_environment   0.518252 0.513827 0.507338           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.34 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.296912 0.305226 0.290895           421
#       behavior_alcohol                2   0.138095 0.152381 0.141270           105
#       behavior_alcohol                3   0.234756 0.271341 0.246612           492
#          behavior_drug                1   0.269231 0.224359 0.237179            26
#          behavior_drug                2   0.020833 0.020833 0.020833            48
#          behavior_drug                3   0.343902 0.323171 0.328049           410
#       behavior_tobacco                1   0.351220 0.300813 0.308780           205
#       behavior_tobacco                2   0.057243 0.063863 0.058567           428
#       behavior_tobacco                3   0.328475 0.354260 0.334978           446
# sdoh_community_present           Absent   0.534483 0.517241 0.517241            29
# sdoh_community_present             Both   0.436782 0.302299 0.329762           116
# sdoh_community_present          Present   0.446835 0.401899 0.414665           790
#         sdoh_economics                1   0.437838 0.439189 0.434595           185
#         sdoh_economics                2   0.366848 0.372283 0.363678           368
#         sdoh_education                1   0.231707 0.203252 0.207317            41
#       sdoh_environment                1   0.511706 0.508919 0.502007           897
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.250491 0.273084 0.254060          1018
#          behavior_drug   0.307851 0.287879 0.292700           484
#       behavior_tobacco   0.225209 0.228916 0.220358          1079
# sdoh_community_present   0.448307 0.393119 0.407313           935
#         sdoh_economics   0.390597 0.394665 0.387402           553
#         sdoh_education   0.231707 0.203252 0.207317            41
#       sdoh_environment   0.509956 0.507190 0.500332           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.35 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.289786 0.296912 0.283769           421
#       behavior_alcohol                2   0.138095 0.152381 0.141270           105
#       behavior_alcohol                3   0.225610 0.259146 0.236450           492
#          behavior_drug                1   0.269231 0.224359 0.237179            26
#          behavior_drug                2   0.020833 0.020833 0.020833            48
#          behavior_drug                3   0.336585 0.315854 0.321138           410
#       behavior_tobacco                1   0.351220 0.298374 0.307154           205
#       behavior_tobacco                2   0.056075 0.061526 0.057009           428
#       behavior_tobacco                3   0.317265 0.343049 0.323767           446
# sdoh_community_present           Absent   0.534483 0.517241 0.517241            29
# sdoh_community_present             Both   0.436782 0.302299 0.329762           116
# sdoh_community_present          Present   0.431646 0.387553 0.400108           790
#         sdoh_economics                1   0.432432 0.433784 0.429189           185
#         sdoh_economics                2   0.355978 0.361413 0.352808           368
#         sdoh_education                1   0.219512 0.178862 0.191057            41
#       sdoh_environment                1   0.507246 0.502230 0.496433           897
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.243124 0.263752 0.246202          1018
#          behavior_drug   0.301653 0.281680 0.286846           484
#       behavior_tobacco   0.220111 0.222892 0.214798          1079
# sdoh_community_present   0.435472 0.380998 0.395014           935
#         sdoh_economics   0.381555 0.385624 0.378360           553
#         sdoh_education   0.219512 0.178862 0.191057            41
#       sdoh_environment   0.505531 0.500553 0.494801           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.36 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.275534 0.283056 0.270705           421
#       behavior_alcohol                2   0.133333 0.142857 0.134921           105
#       behavior_alcohol                3   0.224593 0.251016 0.233062           492
#          behavior_drug                1   0.269231 0.224359 0.237179            26
#          behavior_drug                2   0.020833 0.020833 0.020833            48
#          behavior_drug                3   0.326829 0.306098 0.311382           410
#       behavior_tobacco                1   0.351220 0.295935 0.305528           205
#       behavior_tobacco                2   0.056075 0.061526 0.057009           428
#       behavior_tobacco                3   0.306054 0.327354 0.311061           446
# sdoh_community_present           Absent   0.500000 0.500000 0.494253            29
# sdoh_community_present             Both   0.432471 0.297989 0.325452           116
# sdoh_community_present          Present   0.424051 0.380802 0.393146           790
#         sdoh_economics                1   0.432432 0.433784 0.429189           185
#         sdoh_economics                2   0.346467 0.351902 0.344203           368
#         sdoh_education                1   0.219512 0.178862 0.191057            41
#       sdoh_environment                1   0.497770 0.490524 0.486399           897
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.236248 0.253111 0.238507          1018
#          behavior_drug   0.293388 0.273416 0.278581           484
#       behavior_tobacco   0.215477 0.215941 0.209237          1079
# sdoh_community_present   0.427451 0.374225 0.387884           935
#         sdoh_economics   0.375226 0.379295 0.372634           553
#         sdoh_education   0.219512 0.178862 0.191057            41
#       sdoh_environment   0.496128 0.488938 0.484845           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.37 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.273159 0.274743 0.265954           421
#       behavior_alcohol                2   0.114286 0.123810 0.115873           105
#       behavior_alcohol                3   0.224593 0.248984 0.232385           492
#          behavior_drug                1   0.269231 0.224359 0.237179            26
#          behavior_drug                2   0.020833 0.020833 0.020833            48
#          behavior_drug                3   0.310976 0.289024 0.295122           410
#       behavior_tobacco                1   0.346341 0.291870 0.301463           205
#       behavior_tobacco                2   0.046729 0.052181 0.047664           428
#       behavior_tobacco                3   0.301570 0.320628 0.305830           446
# sdoh_community_present           Absent   0.500000 0.500000 0.494253            29
# sdoh_community_present             Both   0.415230 0.286494 0.312521           116
# sdoh_community_present          Present   0.417722 0.375105 0.387239           790
#         sdoh_economics                1   0.432432 0.428378 0.427387           185
#         sdoh_economics                2   0.342391 0.347826 0.340127           368
#         sdoh_education                1   0.195122 0.170732 0.178862            41
#       sdoh_environment                1   0.494426 0.486622 0.483055           897
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.233301 0.246726 0.234250          1018
#          behavior_drug   0.279959 0.258953 0.264807           484
#       behavior_tobacco   0.208990 0.208681 0.202595          1079
# sdoh_community_present   0.419964 0.367986 0.381289           935
#         sdoh_economics   0.372514 0.374774 0.369319           553
#         sdoh_education   0.195122 0.170732 0.178862            41
#       sdoh_environment   0.492810 0.485066 0.481527           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.38 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.269596 0.267617 0.261203           421
#       behavior_alcohol                2   0.114286 0.123810 0.115873           105
#       behavior_alcohol                3   0.202236 0.223577 0.209350           492
#          behavior_drug                1   0.269231 0.224359 0.237179            26
#          behavior_drug                2   0.020833 0.020833 0.020833            48
#          behavior_drug                3   0.298780 0.278049 0.283740           410
#       behavior_tobacco                1   0.336585 0.282114 0.291707           205
#       behavior_tobacco                2   0.040888 0.047897 0.042835           428
#       behavior_tobacco                3   0.292601 0.309417 0.296114           446
# sdoh_community_present           Absent   0.500000 0.500000 0.494253            29
# sdoh_community_present             Both   0.419540 0.280029 0.312808           116
# sdoh_community_present          Present   0.403797 0.364979 0.375847           790
#         sdoh_economics                1   0.421622 0.417568 0.416577           185
#         sdoh_economics                2   0.336957 0.343750 0.335598           368
#         sdoh_education                1   0.195122 0.170732 0.178862            41
#       sdoh_environment                1   0.489409 0.481048 0.477852           897
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.221022 0.231500 0.221153          1018
#          behavior_drug   0.269628 0.249656 0.255165           484
#       behavior_tobacco   0.201112 0.200494 0.194810          1079
# sdoh_community_present   0.408734 0.358627 0.371698           935
#         sdoh_economics   0.365280 0.368445 0.362688           553
#         sdoh_education   0.195122 0.170732 0.178862            41
#       sdoh_environment   0.487832 0.479535 0.476364           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.39 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.255344 0.253365 0.247743           421
#       behavior_alcohol                2   0.104762 0.109524 0.104762           105
#       behavior_alcohol                3   0.194106 0.211382 0.199864           492
#          behavior_drug                1   0.192308 0.173077 0.179487            26
#          behavior_drug                2   0.020833 0.020833 0.020833            48
#          behavior_drug                3   0.295122 0.273171 0.279675           410
#       behavior_tobacco                1   0.326829 0.274797 0.285203           205
#       behavior_tobacco                2   0.038551 0.045561 0.040498           428
#       behavior_tobacco                3   0.274664 0.286996 0.276682           446
# sdoh_community_present           Absent   0.500000 0.500000 0.494253            29
# sdoh_community_present             Both   0.410920 0.277155 0.308498           116
# sdoh_community_present          Present   0.391772 0.353165 0.364244           790
#         sdoh_economics                1   0.421622 0.417568 0.416577           185
#         sdoh_economics                2   0.338315 0.343750 0.336504           368
#         sdoh_education                1   0.195122 0.170732 0.178862            41
#       sdoh_environment                1   0.481605 0.470457 0.468933           897
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.210216 0.218238 0.209856          1018
#          behavior_drug   0.262397 0.242769 0.248623           484
#       behavior_tobacco   0.190918 0.188909 0.184615          1079
# sdoh_community_present   0.397504 0.348289 0.361360           935
#         sdoh_economics   0.366184 0.368445 0.363291           553
#         sdoh_education   0.195122 0.170732 0.178862            41
#       sdoh_environment   0.480088 0.469027 0.467515           904
#
#
#
#
# -------------------------- TARGET THRESHOLD: thresh_0.4 --------------------------
# ### Performance per category and label ###
#               category prediction_class  precision   recall       f1  sample_count
#       behavior_alcohol                1   0.239905 0.237926 0.233492           421
#       behavior_alcohol                2   0.104762 0.109524 0.104762           105
#       behavior_alcohol                3   0.184959 0.201220 0.190379           492
#          behavior_drug                1   0.192308 0.173077 0.179487            26
#          behavior_drug                2   0.020833 0.020833 0.020833            48
#          behavior_drug                3   0.285366 0.264634 0.270732           410
#       behavior_tobacco                1   0.321951 0.266260 0.280000           205
#       behavior_tobacco                2   0.037383 0.043224 0.038941           428
#       behavior_tobacco                3   0.263453 0.273543 0.264723           446
# sdoh_community_present           Absent   0.465517 0.465517 0.459770            29
# sdoh_community_present             Both   0.400862 0.268534 0.300164           116
# sdoh_community_present          Present   0.382911 0.343671 0.355383           790
#         sdoh_economics                1   0.405405 0.401351 0.400360           185
#         sdoh_economics                2   0.331522 0.332880 0.327899           368
#         sdoh_education                1   0.170732 0.158537 0.162602            41
#       sdoh_environment                1   0.468227 0.455964 0.455556           897
#       sdoh_environment                2   0.285714 0.285714 0.285714             7
#
#
# ### Performance per category ###
#               category  precision   recall       f1  sample_count
#       behavior_alcohol   0.199411 0.206942 0.199378          1018
#          behavior_drug   0.254132 0.235537 0.241047           484
#       behavior_tobacco   0.184893 0.180800 0.178066          1079
# sdoh_community_present   0.387701 0.338128 0.351770           935
#         sdoh_economics   0.356239 0.355787 0.352140           553
#         sdoh_education   0.170732 0.158537 0.162602            41
#       sdoh_environment   0.466814 0.454646 0.454240           904

# %%
import matplotlib.pyplot as plt
from collections import Counter

TARGET_THRESH = "thresh_0.07"

def get_mistake_stats_by_category(df, categories, thresh):
    mistake_results = {}

    for cat in categories:
        if "absent" in cat: continue
        
        ccat = "sdoh_community" if "community" in cat else cat
        ner_label = ccat
        
        fp_list, fn_list = [], []
        
        for _, row in df.iterrows():
            if "community" in cat:
                lime_raw = row.get("sdoh_community_present_thresholds", {}).get(thresh, []) + \
                           row.get("sdoh_community_absent_thresholds", {}).get(thresh, [])
            else:
                lime_raw = row.get(f"{cat}_thresholds", {}).get(thresh, [])

            lime_set = clean_set(lime_raw)
            gt_set = clean_set(row.get("ner_kw", {}).get(ner_label, []))

            fp_list.extend([l for l in lime_set if not any(l == g for g in gt_set)])
            fn_list.extend([g for g in gt_set if not any(g == l for l in lime_set)])

        mistake_results[ccat] = {
            'fp_counts': Counter(fp_list),
            'fn_counts': Counter(fn_list),
            'total_fp': len(fp_list),
            'total_fn': len(fn_list)
        }
    return mistake_results

mistakes = get_mistake_stats_by_category(final_df, categories, TARGET_THRESH)

# %%
MIN_ERROR_COUNT = 1 

for cat, data in mistakes.items():
    print(f"\n{'='*20} CATEGORY ERROR ANALYSIS: {cat} {'='*20}")

    top_fps = data['fp_counts'].most_common(15)
    top_fns = data['fn_counts'].most_common(15)

    if top_fps:
        filtered_fps = [f"{w} ({c})" for w, c in top_fps if c >= MIN_ERROR_COUNT]
        print(f"Top Hallucinations (FPs): {', '.join(filtered_fps) if filtered_fps else 'None'}")
    else:
        print("Top Hallucinations (FPs): No errors found.")
        
    if top_fns:
        filtered_fns = [f"{w} ({c})" for w, c in top_fns if c >= MIN_ERROR_COUNT]
        print(f"Top Blind Spots (FNs):    {', '.join(filtered_fns) if filtered_fns else 'None'}")
    else:
        print("Top Blind Spots (FNs): No errors found.")
# Out:
# ==================== CATEGORY ERROR ANALYSIS: sdoh_community ====================
# Top Hallucinations (FPs): vive (157), historia (153), familiar (113), padre (37), murió (31), madre (29), hermano (24), hijos (22), hermana (21), familia (20), paciente (19), social (17), años (15), examen (14), nombre (14)
# Top Blind Spots (FNs):    hijos (36), esposa (33), hijo (29), hija (27), casado (23), ley (15), madre (15), hijas (13), esposo (12), nietos (12), familia (11), hermano (8), hermana (7), padre (7), hermanos (5)
#
# ==================== CATEGORY ERROR ANALYSIS: sdoh_education ====================
# Top Hallucinations (FPs): escuela (4), grado (4), educación (3), trabaja (3), historia (3), completó (3), colegio (3), universidad (2), secundaria (2), hijos (2), jubilado (2), mba (1), ingeniería (1), bachillerato (1), secretario (1)
# Top Blind Spots (FNs):    educado (2), phd (1), maestro (1), universidad (1), colegio (1), escuela (1), secundaria (1)
#
# ==================== CATEGORY ERROR ANALYSIS: sdoh_economics ====================
# Top Hallucinations (FPs): anteriormente (24), ex (23), social (20), actualmente (18), historia (16), examen (13), tabaco (13), paciente (13), gerente (12), ocupación (12), trabajador (11), usado (11), trabajó (10), drogas (10), ingeniero (8)
# Top Blind Spots (FNs):    trabajó (9), trabajo (6), trabaja (5), trabajar (4), trabajando (3), gerente (3), construcción (3), trabajan (2), ingeniero (2), vive (2), negocios (2), conductor (2), material (2), ocupación (2), propietario (2)
#
# ==================== CATEGORY ERROR ANALYSIS: sdoh_environment ====================
# Top Hallucinations (FPs): vive (93), historia (81), social (55), paciente (43), esposa (42), familia (19), examen (18), actualmente (17), casado (13), casa (11), hogar (11), independiente (11), viven (10), dental (9), viviendo (9)
# Top Blind Spots (FNs):    casa (15), vive (15), rehabilitación (11), hogar (10), enfermería (9), nh (6), ancianos (5), centro (5), apartamento (4), senior (4), apartamentos (3), cuidados (3), vivió (2), instalación (2), vivienda (2)
#
# ==================== CATEGORY ERROR ANALYSIS: behavior_alcohol ====================
# Top Hallucinations (FPs): historia (133), niega (128), tabaco (84), ocasional (65), bebe (51), abuso (49), drogas (36), social (35), nega (34), raro (30), años (30), ocasionalmente (28), etoh (28), familiar (24), vaso (24)
# Top Blind Spots (FNs):    alcohol (65), etoh (42), bebe (12), vino (12), beber (10), cervezas (9), bebida (8), bebidas (7), bebió (6), tob (4), bebía (4), semana (4), vodka (3), bebido (3), whisky (2)
#
# ==================== CATEGORY ERROR ANALYSIS: behavior_tobacco ====================
# Top Hallucinations (FPs): historia (139), años (125), niega (104), dejar (95), etoh (66), social (49), tabaco (45), alcohol (44), ex (37), fumar (31), deja (27), nega (27), fuma (23), actual (21), examen (19)
# Top Blind Spots (FNs):    tabaco (95), ppd (71), paquete (66), paquetes (35), cigarrillos (34), fumar (33), fumó (31), fumado (25), fumador (15), fuma (9), etoh (7), año (7), drogas (7), tob (6), pack (5)
#
# ==================== CATEGORY ERROR ANALYSIS: behavior_drug ====================
# Top Hallucinations (FPs): historia (111), niega (79), alcohol (44), etoh (41), tabaco (36), drogas (26), nega (21), familiar (20), abuso (19), recreativas (16), rechaza (16), iv (12), denies (11), recreativo (9), ilícitas (8)
# Top Blind Spots (FNs):    drogas (30), cocaína (11), ilícitas (9), ivdu (7), heroína (6), sustancias (5), recreativas (5), iv (5), opiáceos (4), ilícito (3), benzos (3), mj (3), marihuana (2), intravenosas (2), metadona (1)
